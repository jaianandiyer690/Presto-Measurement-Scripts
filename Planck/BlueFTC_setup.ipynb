# %% [markdown]
# # BlueFors Temperature Control Setup
# ----

# %% [markdown]
# The BlueFors Temperature Control API allows us to use **HTTP GET/POST** commands to **READ** the status of *CHANNELS* (DR stages) and *HEATERS*, and **WRITE** to the heaters to turn them *ON/OFF*.

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
import time
import os
import h5py
import inspect
from tqdm import tqdm
import sys
import math
import presto
from presto import lockin, utils, hardware
from presto.hardware import AdcFSample, AdcMode, DacFSample, DacMode
from blueftc.BlueforsController import BlueFTController
# Reload credentials module to get latest changes
import importlib
import JPA_credentials
importlib.reload(JPA_credentials)
from JPA_credentials import API_KEY, IP_ADDRESS, PORT_NUMBER, MXC_ID, HEATER_ID, PID_CALIB_FILE

# Timeout for hardware communication
import requests

# BASE URL for interacting with BlueFTC
base_url = 'http://192.168.88.25:5001'

# Print JSON 
def print_JSON(r):
    r_dict = r.json()
    for key, value in r_dict.items():
        print(f"{key}: {value}")

# %% [markdown]
# ## `READ` Endpoints
#
# 1. System information: `/system`
# 2. Device information: `/system/device `
# 3. Network information: `/system/network `
# 4. Channel settings information:
#     - `/channel`
#     - Requires passing a *PAYLOAD* (parameters) such as ``payload = {"channel_nr": 1}``
#     - Executed through a **POST** command
#     - Active channels:
#         1. Channel 1: 50K Plate
#         2. Channel 2: 4K Plate
#         3. Channel 5: Still
#         4. Channel 6: Mixing Chamber
# 5. Channel temperature measurements:
#     - ``/channel/measurement/latest``
#     - Executed through **GET** or **POST** commands
# 6. Heater status:
#     - `/heater`
#     - Requires passing a *PAYLOAD* (parameters) such as ``payload = {"heater_nr": 4}``
#     - Executed through a **POST** command
#     - Heater 4 is for the Mixing Chamber

# %%
# 1. System Information
# =====================
url = base_url + '/system'
print("Requesting...", url, '\n')
r = requests.get(url)

print('SYSTEM INFORMATION \n================')
print_JSON(r)
# Out:
# Requesting... http://192.168.88.25:5001/system
#
# SYSTEM INFORMATION
# ...
# type: Bluefors TC
# api_version: 2
# serial: 149
# label: 149
# addinfo:
# software_version: tc-tc10_1.2.3+cd78bd01.39735
#
# datetime: 2026-03-18T11:35:54.987944Z
# status: OK

# %%
# 2. Device Information
# =====================
url = base_url + '/system/device'
print("Requesting...", url, '\n')
r = requests.get(url)

print('DEVICE INFORMATION \n================')
print_JSON(r)
# Out:
# Requesting... http://192.168.88.25:5001/system/device
#
# DEVICE INFORMATION
# ...
# device_id: 1E70C61C941008201425A000A0000094
# device_firmware: 0.3.11
# datetime: 2026-03-18T11:51:38.593141Z
# status: OK

# %%
# 3. Network Information
# =====================
url = base_url + '/system/network'
print("Requesting...", url, '\n')
r = requests.get(url)

print('NETWORK INFORMATION \n================')
print_JSON(r)
# Out:
# Requesting... http://192.168.88.25:5001/system/network
#
# NETWORK INFORMATION
# ...
# ip_configuration: static
# ip_address: 192.168.88.25
# netmask: 255.255.255.0
# gateway: 192.168.88.1
# state: UP
# mac_address: b8:27:eb:60:e7:b0
# dns: 192.168.88.1
# datetime: 2026-03-18T11:51:39.589232Z
# status: OK

# %%
# 4. Channel Information
# =====================
url = base_url + '/channel'

channel_nr = 1 # 1, 2, 5, 6
payload= {
    'channel_nr': channel_nr
}

print("Requesting...", url, '\n')
r = requests.post(url, json=payload)

print(f'CHANNEL {channel_nr} INFORMATION  ')
print('=======================')
print_JSON(r)
# Out:
# Requesting... http://192.168.88.25:5001/channel
#
# CHANNEL 1 INFORMATION
# ...
# channel_nr: 1
# active: True
# name: PT 50K
# coupled_heater_nr: 0
# excitation_mode: 1
# excitation_current_range: 5
# excitation_cmn_range: 1
# excitation_vmax_range: 2
# use_non_default_timeconstants: False
# wait_time: 7.0
# meas_time: 3.0
# calib_curve_nr: 1
# datetime: 2026-03-18T11:51:45.589424Z
# status: OK

# %%
# 5. Channel Temperature 
# =======================
url = base_url + '/channel/measurement/latest'
print("Requesting...", url, '\n')
r = requests.get(url)

print('CHANNEL TEMPERATURE \n================')
print_JSON(r)
# Out:
# Requesting... http://192.168.88.25:5001/channel/measurement/latest
#
# CHANNEL TEMPERATURE
# ...
# channel_nr: 6
# temperature: 0.009553
# resistance: 8450.421
# reactance: 1002379.606
# angle: 89.516
# magnitude: 8450.12
# rez: 8449.82
# imz: 71.235
# settings_nr: 5
# status_flags: []
# timestamp: 1773834792.721588
# datetime: 2026-03-18T11:53:13.437400Z
# status: OK

# %%
# 6. Heater Information
# =====================
url = base_url + '/heater'

heater_nr = 4 # 1, 2, 3, 4 (Mixing Chamber)
payload= {
    'heater_nr': heater_nr
}

print("Requesting...", url, '\n')
r = requests.post(url, json=payload)

print(f'HEATER {heater_nr} INFORMATION')
print('=======================')
print_JSON(r)
# Out:
# Requesting... http://192.168.88.25:5001/heater
#
# HEATER 4 INFORMATION
# ...
# heater_nr: 4
# active: False
# name: MXC Heater
# pid_mode: 0
# resistance: 120
# power: 9.999999999999999e-06
# target_temperature: 0.01
# target_temperature_shown: False
# control_algorithm: 1
# control_algorithm_settings: {'proportional': 0.001, 'integral': 200.0, 'derivative': 0}
# setpoint: 0.0
# max_power: 4.9999999999999996e-05
# relay_mode: 1
# relay_status: 1
# datetime: 2026-03-18T11:57:30.789225Z
# status: OK

# %% [markdown]
# # `WRITE` Endpoints
#
# Only execute with caution and absolute certainty of what is going to happen!
#
# All write commands return True if executed successfully, otherwise False.
#
# 1. Set heater to specific power:
#     - ``/heater/update``
#     - ``payload = {
#     "heater_nr": 4,
#     "active": True,
#     "pid_mode": 0,
#     "power": 1e-6
# }``

# %%
# 1. Heater Update
# =====================

# Set heater power to X µW
url = base_url + '/heater/update'

heater_nr = 4 # 1, 2, 3, 4 (Mixing Chamber)
payload = {
    "heater_nr": heater_nr,
    "active": True,
    "pid_mode": 0,
    "power": 1e-6
}

print("Requesting...", url, '\n')
r = requests.post(url, json=payload)
print('Heater power successfully set to ', payload['power'], '.')

# Show heater status
url = base_url + '/heater'

heater_nr = 4 # 1, 2, 3, 4 (Mixing Chamber)
payload= {
    'heater_nr': heater_nr
}

print("Requesting...", url, '\n')
r = requests.post(url, json=payload)

print(f'HEATER {heater_nr} INFORMATION')
print('=======================')
print_JSON(r)

# Turn OFF heater
url = base_url + '/heater/update'

heater_nr = 4 # 1, 2, 3, 4 (Mixing Chamber)
payload = {
    "heater_nr": heater_nr,
    "active": False,
}

print("Requesting...", url, '\n')
r = requests.post(url, json=payload)
print('Heater successfully turned off. \n')

# Show heater status
url = base_url + '/heater'

heater_nr = 4 # 1, 2, 3, 4 (Mixing Chamber)
payload= {
    'heater_nr': heater_nr
}

print("Requesting...", url, '\n')
r = requests.post(url, json=payload)

print(f'HEATER {heater_nr} INFORMATION')
print('=======================')
print_JSON(r)
# Out:
# Requesting... http://192.168.88.25:5001/heater/update
#
# Heater power successfully set to  1e-06 .
# Requesting... http://192.168.88.25:5001/heater
#
# HEATER 4 INFORMATION
# ...
# heater_nr: 4
# active: True
# name: MXC Heater
# pid_mode: 0
# resistance: 120
# power: 1e-06
# target_temperature: 0.01
# target_temperature_shown: False
# control_algorithm: 1
# control_algorithm_settings: {'proportional': 0.001, 'integral': 200.0, 'derivative': 0}
# setpoint: 0.0
# max_power: 4.9999999999999996e-05
# relay_mode: 1
# relay_status: 1
# datetime: 2026-03-18T12:15:30.189562Z
# status: OK
# Requesting... http://192.168.88.25:5001/heater/update
#
# Heater successfully turned off.
#
# Requesting... http://192.168.88.25:5001/heater
#
# HEATER 4 INFORMATION
# ...
# heater_nr: 4
# active: False
# name: MXC Heater
# pid_mode: 0
# resistance: 120
# power: 1e-06
# target_temperature: 0.01
# target_temperature_shown: False
# control_algorithm: 1
# ...

# %% [markdown]
# ### MXC Temperature ($T_{MXC}$) v.s. Heater Power ($P_{MXC}$)
#
# Here investigate the stabilized mixing chamber temperature as we ramp up the heater power.
#
# 1. $P_{MXC} = 1\mu W $
#     - Get T_MXC -- DONE
#     - Plot T_MXC continuously -- DONE
#     - Check if temperature trace satisfies stabilization criterion
#     - Save temperature
# 2. Power sweep
#     - Repeat for different heater powers

# %%
# Get stabilized temperature
# ==========================

def get_stable_temp(N_runs):
    stability_status = False

    runs = np.arange(
        start= 1, 
        stop= N_runs + 1, 
        step= 1
        )
    
    temp_trace = np.zeros(len(runs))

    # Start running temperature plot
    # ==============================

    fig, ax = plt.subplots(
        figsize = (6,6),
        dpi = 125,
    ) 

    line, = ax.plot(
        [], 
        [], 
        label= '$T_{MXC}$',
        marker = 'o'
        )
    ax.set_xlabel('Run')
    ax.set_ylabel('Temperature (mK)')
    ax.set_xlim(0, N_runs)
    ax.set_ylim(0, 20)
    ax.grid()
    ax.legend()

    display(fig)

    for i in range(len(runs)):

        # Reset channel index and wait until channel 6 measurement is received
        channel = 1
        while channel != 6:

            # Get channel measurement
            url = base_url + '/channel/measurement/latest'
            print("Requesting T_MXC")
            r = requests.get(url)
            r_dict = r.json()

            # Retry if wrong channel        
            channel = r_dict['channel_nr']
            if channel != 6: 
                print('Waiting for Channel 6...')
                time.sleep(2)

        # Sleep until next measurement cycle 
        time.sleep(10)

        # Get T_MXC
        temp_trace[i] = r_dict['temperature'] * 1e3 # mK

        # Print current temperature
        print('T_MXC = ', temp_trace[i])

        # Add to scatter plot
        line.set_data(runs[:i+1], temp_trace[:i+1])
        ax.relim()
        ax.autoscale_view(scaley=True)
        clear_output(wait=True)
        display(fig)

        # Stability criterion
        n_stable = 10
        stability_threshold = 0.2
        if i < n_stable: pass # Wait until enough data points have accumulated
        elif i>= n_stable: 

            # Create sublist of last 5 temperature readings
            L5_temp_trace = temp_trace[i-n_stable + 1: i + 1]
            stability = np.std(L5_temp_trace)
            L5_temp_mean =  np.round(np.mean(L5_temp_trace), 2)

            # If STD of L5 readings > 2mk: keep reading
            if stability > stability_threshold: 

                # Print still running status
                print('Temperature not stabilized')

            elif stability <= stability_threshold:

                # Print stabilized temperature
                print('Temperature stabilized at ', L5_temp_mean, ' mK')

                plt.close(fig)

                return L5_temp_mean, stability_status

# %%
# Run heater, get stable temperature, turn off heater

def get_stable_temp_ON(heater_power, N_runs):

    # Set heater power to X µW
    # ========================
    url = base_url + '/heater/update'

    heater_nr = 4 # 1, 2, 3, 4 (Mixing Chamber)
    payload = {
        "heater_nr": heater_nr,
        "active": True,
        "pid_mode": 0,
        "power": heater_power
    }

    print("Requesting...", url, '\n')
    r = requests.post(url, json=payload)
    print('Heater power successfully set to ', payload['power'] * 1e6, 'µW.')

    # Wait until temperature stabilized
    stable_temp = get_stable_temp(N_runs=N_runs)

    # Turn OFF heater
    url = base_url + '/heater/update'

    heater_nr = 4 # 1, 2, 3, 4 (Mixing Chamber)
    payload = {
        "heater_nr": heater_nr,
        "active": False,
    }

    print("Requesting...", url, '\n')
    r = requests.post(url, json=payload)
    print('Heater successfully turned off. \n')

    # Show heater status
    url = base_url + '/heater'

    heater_nr = 4 # 1, 2, 3, 4 (Mixing Chamber)
    payload= {
        'heater_nr': heater_nr
    }

    r = requests.post(url, json=payload)

    print(f'HEATER {heater_nr} INFORMATION')
    print('=======================')
    print_JSON(r)

    return stable_temp


# Test run
T_1muW = get_stable_temp_ON(
    heater_power=5e-6,
    N_runs=20
)

print(T_1muW)
# Out:
# Temperature not stabilized
# Requesting T_MXC
# Waiting for Channel 6...
# Requesting T_MXC
# Waiting for Channel 6...
# Requesting T_MXC
# Waiting for Channel 6...
# Requesting T_MXC
# Waiting for Channel 6...
# Requesting T_MXC
# Waiting for Channel 6...
# Requesting T_MXC
# Waiting for Channel 6...
# Requesting T_MXC
# Waiting for Channel 6...
# Requesting T_MXC
# Waiting for Channel 6...
# Requesting T_MXC
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[103], line 55
#      51     return stable_temp
#      54 # Test run
# ---> 55 T_1muW = get_stable_temp_ON(
#      56     heater_power=5e-6,
#      57     N_runs=20
#      58 )
#      60 print(T_1muW)
#
# Cell In[103], line 22, in get_stable_temp_ON(heater_power, N_runs)
#      19 print('Heater power successfully set to ', payload['power'] * 1e6, 'µW.')
#      21 # Wait until temperature stabilized
# ...
